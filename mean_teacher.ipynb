# %% [markdown]
# ## Google colab setup

# %%
try:
  import google.colab
  IS_COLAB = True
except:
  IS_COLAB = False

# %%
if IS_COLAB:
  # !pip install tensorflow_addons
  # !pip install unidecode
  # !pip install transformers
  # !pip install nlpaug

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp /content/drive/MyDrive/SemiSupervised/*.csv .

# %% [markdown]
# ## Imports and setup

# %%
# %%capture
import tensorflow as tf
import tensorflow_addons as tfa
import pandas as pd
import re
import time
import spacy
import numpy as np
from transformers import AutoTokenizer, TFAutoModel
from unidecode import unidecode
# Out:
# 2023-03-10 08:24:52.334498: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-10 08:24:52.877508: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.1/lib64:/usr/local/cuda-10.2/lib64:/usr/local/cuda/extras/CUPTI/lib64::/usr/local/cuda-10.1/lib64:/usr/local/cuda-10.2/lib64:/usr/local/cuda/extras/CUPTI/lib64:
# 2023-03-10 08:24:52.877568: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.1/lib64:/usr/local/cuda-10.2/lib64:/usr/local/cuda/extras/CUPTI/lib64::/usr/local/cuda-10.1/lib64:/usr/local/cuda-10.2/lib64:/usr/local/cuda/extras/CUPTI/lib64:
# 2023-03-10 08:24:52.877573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-10 08:24:53.543627: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:24:53.543883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:24:53.547496: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:24:53.547739: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:24:53.547998: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:24:53.548221: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
gpus = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(gpus[1], 'GPU')

# %% [markdown]
# ## Utils

# %%
data = pd.read_csv("train_ner.csv")

# %%
def preprocess(x):
    s = unidecode(x)
    s = str.lower(s)
    s = re.sub(r"\[[a-z]+\]","", s)
    s = re.sub(r"\*","", s)
    s = re.sub(r"[^a-zA-Z0-9]+"," ",s)
    s = re.sub(r" +"," ",s)
    s = re.sub(r"(.)\1+",r"\1",s)

    return s

# %%
label_ids = {label_name:i for i, label_name in enumerate(sorted(set(data["label"])))}
label_ids
# Out:
# {'ABUSE': 0, 'INSULT': 1, 'OTHER': 2, 'PROFANITY': 3}

# %%
data["preprocessed"] = data["text"].apply(preprocess)
data.head()
# Out:
#       id                                               text   label  \
# 0  32674  da de unde stii u mai [ORG] ca banii au fost p...   ABUSE
# 1  16514  m*uie [PERS] m*uie [PERS] ... m*uie\nbai kakat...  INSULT
# 2  32556  PT ALA CARE ARE TREABA CU [PERS]!!ESTI UNUL CA...   OTHER
# 3  23861  sunt bucuros ca [PERS] nu a mai venit la [ORG]...   OTHER
# 4  21811  [PERS] esti....PE..N\n ES..CU..LI..BI.L!!! te ...  INSULT
#
#                                         preprocessed
# 0  da de unde sti u mai ca bani au fost pt si nu ...
# 1  muie muie muie bai kakatule stai in banca ta d...
# 2  pt ala care are treaba cu esti unul care nu ar...
# 3  sunt bucuros ca nu a mai venit la jucator de d...
# 4   esti pe n es cu li bi l te asemeni cu de la c...

# %%
data["class"] = data["label"].map(lambda x: label_ids[x])
data.head(5)
# Out:
#       id                                               text   label  \
# 0  32674  da de unde stii u mai [ORG] ca banii au fost p...   ABUSE
# 1  16514  m*uie [PERS] m*uie [PERS] ... m*uie\nbai kakat...  INSULT
# 2  32556  PT ALA CARE ARE TREABA CU [PERS]!!ESTI UNUL CA...   OTHER
# 3  23861  sunt bucuros ca [PERS] nu a mai venit la [ORG]...   OTHER
# 4  21811  [PERS] esti....PE..N\n ES..CU..LI..BI.L!!! te ...  INSULT
#
#                                         preprocessed  class
# 0  da de unde sti u mai ca bani au fost pt si nu ...      0
# 1  muie muie muie bai kakatule stai in banca ta d...      1
# 2  pt ala care are treaba cu esti unul care nu ar...      2
# 3  sunt bucuros ca nu a mai venit la jucator de d...      2
# 4   esti pe n es cu li bi l te asemeni cu de la c...      1

# %%
data["label"].value_counts()
# Out:
# OTHER        3649
# ABUSE        2768
# INSULT       2242
# PROFANITY    1294
# Name: label, dtype: int64

# %% [markdown]
# ## Prepare data splits

# %%
tok_robert = AutoTokenizer.from_pretrained("readerbench/RoBERT-base")
robert = TFAutoModel.from_pretrained("readerbench/RoBERT-base")
# Out:
# 2023-03-10 08:25:07.775727: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-10 08:25:07.776285: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:07.776598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:07.776853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:08.152736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:08.153053: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:08.153382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-03-10 08:25:08.153619: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-10 08:25:08.153638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6646 MB memory:  -> device: 1, name: GeForce RTX 2070 SUPER, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
def split_ssl_data(ids_array,mask_array,labels,num_classes,label_percent):
  labeled = None
  unlabeled = None

  for class_idx in range(num_classes):
    class_ids = ids_array[labels==class_idx]
    class_mask = mask_array[labels==class_idx]
    sz = int(label_percent * class_ids.shape[0])

    labels_reduced = labels[labels==class_idx][:sz]
    labeled_ids, unlabeled_ids = class_ids[:sz], class_ids[sz:]
    labeled_mask, unlabeled_mask = class_mask[:sz], class_mask[sz:]

    if not labeled:
      labeled = (labeled_ids, labeled_mask, labels_reduced)
      unlabeled = (unlabeled_ids, unlabeled_mask)
    else:
      labeled = (
          np.concatenate([labeled[0],labeled_ids]),
          np.concatenate([labeled[1],labeled_mask]),
          np.concatenate([labeled[2],labels_reduced])
      )
      unlabeled = (
          np.concatenate([unlabeled[0],unlabeled_ids]),
          np.concatenate([unlabeled[1],unlabeled_mask]),
      )

  return labeled, unlabeled

# %%
def preprocess_robert(x):
  t = tok_robert(x,padding="max_length",max_length=96,truncation=True,return_tensors='np')
  return t["input_ids"], t["attention_mask"]

def map_func(input_ids, masks, labels):
  return {'input_ids': input_ids, 'attention_mask': masks}, labels

def map_func2(input_ids, masks):
  return {'input_ids': input_ids, 'attention_mask': masks}

def prepare_ds(filename,batch_size=64,label_percent=0.8):
  df = pd.read_csv(filename)
  X_id_mask = df['text'].map(preprocess).apply(preprocess_robert).apply(pd.Series)

  X_id_mask.columns = ["input_ids","attention_mask"]

  ids_array = np.squeeze(np.stack(X_id_mask.input_ids.values), axis=1)
  mask_array = np.squeeze(np.stack(X_id_mask.attention_mask.values), axis=1)
  labels = df["label"].map(lambda x: label_ids[x]).values

  res_ds = tf.data.Dataset.from_tensor_slices((ids_array, mask_array, labels)).map(map_func).shuffle(len(df)).batch(batch_size)
  return res_ds

# %%
def prepare_train_ds(filename,batch_size=16,label_percent=0.05):
  df = pd.read_csv(filename)
  X_id_mask = df['text'].map(preprocess).apply(preprocess_robert).apply(pd.Series)

  X_id_mask.columns = ["input_ids","attention_mask"]

  ids_array = np.squeeze(np.stack(X_id_mask.input_ids.values), axis=1)
  mask_array = np.squeeze(np.stack(X_id_mask.attention_mask.values), axis=1)
  labels = df["label"].map(lambda x: label_ids[x]).values

  labeled, unlabeled = split_ssl_data(ids_array,mask_array,labels,len(label_ids),label_percent)
  labeled_ds = tf.data.Dataset.from_tensor_slices(labeled)
  labeled_ds = labeled_ds.map(map_func).shuffle(len(labeled_ds)).batch(4*batch_size).repeat()
  unlabeled_ds = tf.data.Dataset.from_tensor_slices(unlabeled)
  unlabeled_ds = unlabeled_ds.map(map_func2).shuffle(len(unlabeled_ds)).batch(4*batch_size).repeat()
  
  return labeled_ds, unlabeled_ds

# %%
labeled_ds, unlabeled_ds = prepare_train_ds("train_ner.csv")
test_ds = prepare_ds("test_ner.csv")
val_ds = prepare_ds("validation_internal_ner.csv")

# %% [markdown]
# ## Model definition and declaration

# %%
class ClsModel(tf.keras.Model):
  def __init__(self,bert_model,num_classes=4,**kwargs):
    super(ClsModel,self).__init__(**kwargs)
    self.bert = bert_model
    self.bert.trainable = False
    self.num_classes = num_classes
    self.noise = tf.keras.layers.GaussianNoise(stddev=1)

    self.cls_head = tf.keras.Sequential([
        tf.keras.layers.Bidirectional(
            tf.keras.layers.LSTM(10,recurrent_dropout=0.2),
            merge_mode="ave"
        ),
        tf.keras.layers.Dense(units=self.num_classes,activation="softmax")
    ])


  def call(self, inputs, training):
    ids, mask = inputs
    
    embeds = self.bert(input_ids=ids, attention_mask=mask).last_hidden_state
    embeds = self.noise(embeds,training=training)
    out = self.cls_head(embeds,training=training)

    return out

# %%
student = ClsModel(bert_model=robert)
teacher = ClsModel(bert_model=robert)

# %% [markdown]
# ## Train and evaluate

# %%
optim = tfa.optimizers.AdamW(weight_decay=0.001,learning_rate=0.005)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
unsup_fn = tf.keras.losses.MeanSquaredError()
val_acc_metric = tf.keras.metrics.SparseCategoricalAccuracy()
val_prec_metric = tf.keras.metrics.Precision(name="precision")
val_recall_metric = tf.keras.metrics.Recall(name="recall")
f1_metric_micro = tfa.metrics.F1Score(num_classes=4, threshold=0.5, average='micro', name='f1_micro')
f1_metric_macro = tfa.metrics.F1Score(num_classes=4, threshold=0.5, average='macro', name='f1_macro')

# %%
def weight_schedule(t, init_period, final_period, max_period):

  if t < init_period:
    x = t / init_period
    return 2.71 ** (-5*(x-1)**2)
  elif t < max_period - final_period:
    return 1.0
  else:
    x = (t - max_period + final_period) / final_period
    return 1 - 2.71 ** (-5*(x-1)**2)

# %%
unsup_weight = tf.Variable(1.0)
ema_decay = 0.99
epochs = 20
steps_per_epoch = 151
max_period = epochs * steps_per_epoch

init_period = 200
final_period = 200

# %%
ema = tf.train.ExponentialMovingAverage(decay=ema_decay)

# %%
@tf.function
def train_step(x,y,xu,unsup_weight):

  with tf.GradientTape() as tape:
      pred_stud = student([x["input_ids"],x["attention_mask"]],training=True)
      pred_teacher = teacher([x["input_ids"],x["attention_mask"]],training=True)
      
      pred2_stud = student([xu["input_ids"],xu["attention_mask"]],training=True)
      pred2_teacher = teacher([xu["input_ids"],xu["attention_mask"]],training=True)
      ls = loss_fn(y, pred_stud)
      lu = unsup_fn(pred_stud, pred_teacher)
      lu2 = unsup_fn(pred2_stud,pred2_teacher)

      loss = ls + unsup_weight * (lu + lu2)

  grads = tape.gradient(loss, student.trainable_weights)
  optim.apply_gradients(zip(grads, student.trainable_weights))
  ema.apply(student.trainable_variables)

  return loss


@tf.function
def test_step(x, y):
    wpred = teacher([x["input_ids"],x["attention_mask"]], training=False)
    val_acc_metric.update_state(y, wpred)
    true_hot = tf.one_hot(y, 4)
    val_prec_metric.update_state(true_hot, wpred)
    val_recall_metric.update_state(true_hot, wpred)
    f1_metric_micro.update_state(true_hot, wpred)
    f1_metric_macro.update_state(true_hot, wpred)

# %%
max_val_acc = 0.0
best_weights = None
l_iter = iter(labeled_ds)
u_iter = iter(unlabeled_ds)
t_step = 0
for epoch in range(epochs):
  print(f"Epoch {epoch}")
  start_time = time.time()

  for step in range(steps_per_epoch):
    x, y = next(l_iter)
    xu = next(u_iter)
    
    unsup_val = weight_schedule(t_step, init_period, final_period, max_period)
    unsup_weight.assign(unsup_val)

    loss = train_step(x,y,xu,unsup_weight)

    teacher_vars = teacher.trainable_variables
    for i,var in enumerate(student.trainable_variables):
      teacher_vars[i].assign(ema.average(var))
    if step % 50 == 0:
      print(
        "Training loss (for one batch) at step %d: %.4f"
        % (step, float(loss))
      )
    t_step+=1
  for x_batch_val, y_batch_val in val_ds:
      test_step(x_batch_val, y_batch_val)

  acc = float(val_acc_metric.result())
  prec = float(val_prec_metric.result())
  recall = float(val_recall_metric.result())
  micro = float(f1_metric_micro.result())
  macro = float(f1_metric_macro.result())

  val_acc_metric.reset_states()
  val_prec_metric.reset_states()
  val_recall_metric.reset_states()
  f1_metric_micro.reset_states()
  f1_metric_macro.reset_states()

  if acc > max_val_acc:
    max_val_acc = acc
    best_weights = teacher.get_weights()
  print(f"Validation acc: {acc:.3f} precision: {prec:.3f} recall: {recall:.3f} f1_micro: {micro:.3f} f1_macro: {macro:.3f}")
  print("Time taken: %.2fs" % (time.time() - start_time))
print("Restoring best weights relative to validation accuracy...")
teacher.set_weights(best_weights)
# Out:
# Epoch 0
# Training loss (for one batch) at step 0: 1.4525
# Training loss (for one batch) at step 50: 1.2298
# Training loss (for one batch) at step 100: 1.0083
# Training loss (for one batch) at step 150: 0.8646
# Validation acc: 0.526 precision: 0.648 recall: 0.272 f1_micro: 0.383 f1_macro: 0.185
# Time taken: 237.37s
# Epoch 1
# Training loss (for one batch) at step 0: 0.8369
# Training loss (for one batch) at step 50: 0.7594
# Training loss (for one batch) at step 100: 0.8233
# Training loss (for one batch) at step 150: 0.6350
# Validation acc: 0.542 precision: 0.592 recall: 0.459 f1_micro: 0.517 f1_macro: 0.363
# Time taken: 200.00s
# Epoch 2
# Training loss (for one batch) at step 0: 0.6552
# Training loss (for one batch) at step 50: 0.6777
# Training loss (for one batch) at step 100: 0.6165
# Training loss (for one batch) at step 150: 0.6532
# Validation acc: 0.557 precision: 0.592 recall: 0.487 f1_micro: 0.534 f1_macro: 0.422
# Time taken: 187.69s
# Epoch 3
# Training loss (for one batch) at step 0: 0.5777
# Training loss (for one batch) at step 50: 0.5492
# Training loss (for one batch) at step 100: 0.6253
# Training loss (for one batch) at step 150: 0.6299
# Validation acc: 0.550 precision: 0.580 recall: 0.499 f1_micro: 0.536 f1_macro: 0.446
# Time taken: 187.38s
# Epoch 4
# Training loss (for one batch) at step 0: 0.5551
# Training loss (for one batch) at step 50: 0.4839
# Training loss (for one batch) at step 100: 0.5271
# Training loss (for one batch) at step 150: 0.4134
# Validation acc: 0.547 precision: 0.573 recall: 0.515 f1_micro: 0.542 f1_macro: 0.453
# Time taken: 187.68s
# Epoch 5
# Training loss (for one batch) at step 0: 0.4400
# Training loss (for one batch) at step 50: 0.3942
# Training loss (for one batch) at step 100: 0.3858
# Training loss (for one batch) at step 150: 0.4739
# Validation acc: 0.547 precision: 0.572 recall: 0.522 f1_micro: 0.546 f1_macro: 0.462
# Time taken: 187.50s
# Epoch 6
# Training loss (for one batch) at step 0: 0.3994
# Training loss (for one batch) at step 50: 0.3612
# Training loss (for one batch) at step 100: 0.4391
# Training loss (for one batch) at step 150: 0.4164
# Validation acc: 0.551 precision: 0.574 recall: 0.522 f1_micro: 0.547 f1_macro: 0.463
# Time taken: 187.70s
# Epoch 7
# Training loss (for one batch) at step 0: 0.4648
# Training loss (for one batch) at step 50: 0.4272
# Training loss (for one batch) at step 100: 0.6174
# Training loss (for one batch) at step 150: 0.4384
# Validation acc: 0.555 precision: 0.575 recall: 0.529 f1_micro: 0.551 f1_macro: 0.474
# Time taken: 186.25s
# Epoch 8
# Training loss (for one batch) at step 0: 0.3359
# Training loss (for one batch) at step 50: 0.3153
# Training loss (for one batch) at step 100: 0.4096
# Training loss (for one batch) at step 150: 0.4070
# Validation acc: 0.545 precision: 0.575 recall: 0.514 f1_micro: 0.543 f1_macro: 0.468
# Time taken: 187.20s
# Epoch 9
# Training loss (for one batch) at step 0: 0.4754
# Training loss (for one batch) at step 50: 0.3400
# Training loss (for one batch) at step 100: 0.3173
# Training loss (for one batch) at step 150: 0.3691
# Validation acc: 0.546 precision: 0.569 recall: 0.526 f1_micro: 0.547 f1_macro: 0.465
# Time taken: 187.01s
# Epoch 10
# Training loss (for one batch) at step 0: 0.3908
# Training loss (for one batch) at step 50: 0.4663
# Training loss (for one batch) at step 100: 0.4195
# Training loss (for one batch) at step 150: 0.3059
# Validation acc: 0.551 precision: 0.570 recall: 0.525 f1_micro: 0.547 f1_macro: 0.466
# Time taken: 187.36s
# Epoch 11
# Training loss (for one batch) at step 0: 0.3858
# Training loss (for one batch) at step 50: 0.3614
# Training loss (for one batch) at step 100: 0.4172
# Training loss (for one batch) at step 150: 0.3498
# Validation acc: 0.551 precision: 0.576 recall: 0.531 f1_micro: 0.553 f1_macro: 0.462
# Time taken: 187.37s
# Epoch 12
# Training loss (for one batch) at step 0: 0.3585
# Training loss (for one batch) at step 50: 0.4316
# Training loss (for one batch) at step 100: 0.2173
# Training loss (for one batch) at step 150: 0.3704
# Validation acc: 0.551 precision: 0.568 recall: 0.530 f1_micro: 0.549 f1_macro: 0.468
# Time taken: 187.50s
# Epoch 13
# Training loss (for one batch) at step 0: 0.4075
# Training loss (for one batch) at step 50: 0.5092
# Training loss (for one batch) at step 100: 0.3213
# Training loss (for one batch) at step 150: 0.3112
# Validation acc: 0.549 precision: 0.574 recall: 0.531 f1_micro: 0.552 f1_macro: 0.471
# Time taken: 187.75s
# Epoch 14
# Training loss (for one batch) at step 0: 0.3193
# Training loss (for one batch) at step 50: 0.2747
# Training loss (for one batch) at step 100: 0.3954
# Training loss (for one batch) at step 150: 0.2639
# Validation acc: 0.547 precision: 0.565 recall: 0.528 f1_micro: 0.546 f1_macro: 0.461
# Time taken: 186.23s
# Epoch 15
# Training loss (for one batch) at step 0: 0.2555
# Training loss (for one batch) at step 50: 0.4747
# Training loss (for one batch) at step 100: 0.2532
# Training loss (for one batch) at step 150: 0.2928
# Validation acc: 0.549 precision: 0.564 recall: 0.530 f1_micro: 0.547 f1_macro: 0.463
# Time taken: 186.79s
# Epoch 16
# Training loss (for one batch) at step 0: 0.3544
# Training loss (for one batch) at step 50: 0.2809
# Training loss (for one batch) at step 100: 0.3005
# Training loss (for one batch) at step 150: 0.2818
# Validation acc: 0.546 precision: 0.561 recall: 0.525 f1_micro: 0.542 f1_macro: 0.454
# Time taken: 186.97s
# Epoch 17
# Training loss (for one batch) at step 0: 0.3571
# Training loss (for one batch) at step 50: 0.2392
# Training loss (for one batch) at step 100: 0.2754
# Training loss (for one batch) at step 150: 0.3699
# Validation acc: 0.554 precision: 0.567 recall: 0.529 f1_micro: 0.547 f1_macro: 0.460
# Time taken: 187.34s
# Epoch 18
# Training loss (for one batch) at step 0: 0.3903
# Training loss (for one batch) at step 50: 0.4001
# Training loss (for one batch) at step 100: 0.4273
# Training loss (for one batch) at step 150: 0.2919
# Validation acc: 0.545 precision: 0.563 recall: 0.526 f1_micro: 0.544 f1_macro: 0.462
# Time taken: 187.69s
# Epoch 19
# Training loss (for one batch) at step 0: 0.3092
# Training loss (for one batch) at step 50: 0.3304
# Training loss (for one batch) at step 100: 0.1698
# Training loss (for one batch) at step 150: 0.3313
# Validation acc: 0.553 precision: 0.566 recall: 0.530 f1_micro: 0.547 f1_macro: 0.465
# Time taken: 187.54s
# Restoring best weights relative to validation accuracy...

# %%
for x_batch_val, y_batch_val in test_ds:
    test_step(x_batch_val, y_batch_val)
acc = float(val_acc_metric.result())
prec = float(val_prec_metric.result())
recall = float(val_recall_metric.result())
micro = float(f1_metric_micro.result())
macro = float(f1_metric_macro.result())

val_acc_metric.reset_states()
val_prec_metric.reset_states()
val_recall_metric.reset_states()
f1_metric_micro.reset_states()
f1_metric_macro.reset_states()
print(f"Test acc: {acc:.3f} precision: {prec:.3f} recall: {recall:.3f} f1_micro: {micro:.3f} f1_macro: {macro:.3f}")
# Out:
# Test acc: 0.557 precision: 0.602 recall: 0.492 f1_micro: 0.541 f1_macro: 0.431
